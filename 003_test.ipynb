# %%
singers = ['Whitney', 'Aretha', 'CeCe', 'JHud']
family_names = ['Houston', 'Franklin', 'Winans', 'Hudson']
full_names = []

for first, family in zip(singers, family_names):
    full_names.append(first + ' ' + family)

print(full_names)
# Out:
# ['Whitney Houston', 'Aretha Franklin', 'CeCe Winans', 'JHud Hudson']
